# %%
# %pip install beautifulsoup4
# %pip install textblob
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/143.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/143.0 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/143.0 kB 217.9 kB/s eta 0:00:01
#      ------------------ ------------------ 71.7/143.0 kB 357.2 kB/s eta 0:00:01
#      ------------------------------------ 143.0/143.0 kB 653.9 kB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.5
# Note: you may need to restart the kernel to use updated packages.
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/636.8 kB ? eta -:--:--
#      - ----------------------------------- 30.7/636.8 kB 217.9 kB/s eta 0:00:03
#      -- ---------------------------------- 41.0/636.8 kB 245.8 kB/s eta 0:00:03
#      ---- -------------------------------- 71.7/636.8 kB 393.8 kB/s eta 0:00:02
#      -------- --------------------------- 143.4/636.8 kB 655.8 kB/s eta 0:00:01
#      --------------- -------------------- 266.2/636.8 kB 862.0 kB/s eta 0:00:01
#      ----------------------- -------------- 399.4/636.8 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------  634.9/636.8 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 636.8/636.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\hp\anaconda3\envs\nen\lib\site-packages (from textblob) (3.2.4)
# Requirement already satisfied: six in c:\users\hp\anaconda3\envs\nen\lib\site-packages (from nltk>=3.1->textblob) (1.16.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Reading Dataset

# %%
# disable warning
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/twitter_sentiment.csv', header=None, index_col=[0])
df = df[[2,3]].reset_index(drop=True)
df.columns = ['sentiment', 'text']
df.head()
# Out:
#   sentiment                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
df.info()

df.isnull().sum()

df.dropna(inplace=True)

df = df[df['text'].apply(len)>1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75682 entries, 0 to 75681
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  75682 non-null  object
#  1   text       74996 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative      22530
# Positive      20844
# Neutral       18285
# Irrelevant    12988
# Name: count, dtype: int64

# %%
import data_process.preprocessing as pr

# %%
df = pr._get_basic_features(df)

# %%
df.columns
# Out:
# Index(['sentiment', 'text', 'char_counts', 'word_counts', 'avg_wordlength',
#        'stopwords_counts', 'hashtag_counts', 'mentions_counts',
#        'digits_counts', 'uppercase_counts'],
#       dtype='object')

# %%
# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# plot 2x4 grid histogram for each numerical feature
plt.figure(figsize=(20,10))

num_cols = df.select_dtypes(include='number').columns

for col in num_cols:
    plt.subplot(2,4, num_cols.get_loc(col)+1)
    sns.kdeplot(data=df, x=col, hue='sentiment', fill=True)

# %%
df['sentiment'].value_counts().plot(kind='pie', autopct='%1.0f%%')

# word cloud
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
plt.figure(figsize=(40,20))

for index, col in enumerate(df['sentiment'].unique()):
    plt.subplot(2,2, index+1)
    # print(col)
    df1 = df[df['sentiment']==col]
    data = df1['text']
    wordcloud = WordCloud(background_color='white', stopwords=stopwords, max_words=500, max_font_size=40, scale=5).generate(str(data))
    # fig = plt.figure(figsize=(15,15))
    # plt.axis('off')
    # disable ticks
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wordcloud)
    plt.title(col, fontsize=40)
    
plt.show()
plt.tight_layout()

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.9.4-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Downloading lxml-4.9.4-cp310-cp310-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 326.8 kB/s eta 0:00:12
#    - -------------------------------------- 0.1/3.8 MB 853.3 kB/s eta 0:00:05
#    --- ------------------------------------ 0.3/3.8 MB 1.6 MB/s eta 0:00:03
#    ------ --------------------------------- 0.6/3.8 MB 2.5 MB/s eta 0:00:02
#    --------- ------------------------------ 0.9/3.8 MB 3.3 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 4.0 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 4.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.9/3.8 MB 4.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.2/3.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.7/3.8 MB 5.1 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------ --- 3.4/3.8 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 5.4 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
df['text'] = df['text'].apply(lambda x: x.lower())
df['text'] = df['text'].apply(lambda x: pr._remove_urls(x))
df['text'] = df['text'].apply(lambda x: pr._remove_special_chars(x))
df['text'] = df['text'].apply(lambda x: pr._remove_rt(x))

# %%
from bs4 import BeautifulSoup

df['text'] = df['text'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

# %%
df.head()
# Out:
#   sentiment                                               text  char_counts  \
# 0  Positive  im getting on borderlands and i will murder yo...           43
# 1  Positive  i am coming to the borders and i will kill you...           40
# 2  Positive  im getting on borderlands and i will kill you all           41
# 3  Positive  im coming on borderlands and i will murder you...           42
# 4  Positive  im getting on borderlands 2 and i will murder ...           46
#
#    word_counts  avg_wordlength  stopwords_counts  hashtag_counts  \
# 0           11        3.909091                 6               0
# 1           12        3.333333                 6               0
# 2           10        4.100000                 5               0
# 3           10        4.200000                 5               0
# 4           12        3.833333                 6               0
#
#    mentions_counts  digits_counts  uppercase_counts
# 0                0              1                 0
# 1                0              1                 2
# 2                0              1                 0
# 3                0              1                 0
# 4                0              2                 0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((59717,), (14930,))

# %%
# %%time
# model building
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

clf = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')), ('clf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])
clf.fit(X_train, y_train)

# evaluation
from sklearn.metrics import accuracy_score

predictions = clf.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.9054253181513731
# CPU times: total: 31min 24s
# Wall time: 7min 22s

# %%
# save model
import pickle

pickle.dump(clf, open('sentiment_analysis.pkl', 'wb'))

# %%
X_test.tolist()[:20]
# Out:
# ['add 4 callofduty and in roguecompany now teams o and everyone plays under play _ pso2 or ghostrecon i am also one of the best grovers in paladinsgame and best junkrat or mccree in overwatchleague dont forget best vulcan in smitegame i play destinythegame and fortnitegame',
#  'tmobile you guys kids are really very slow in tuba star city az makes people go to google verizon',
#  'i will make google top ranking high quality seo backlinks fiverrcom share nwewvp',
#  'i know a guy whos tablet crashes today after 10 years he tried to fix it without google videos and plugging the tv into a different outlet no luck',
#  'eamaddennfl movement is incredible',
#  'internship manager',
#  'bgs not in first by hearthstonebattlegrounds gameforcejphearthstonee3',
#  'almost 2 years after launch and 3 cancelled season later bfv still now have game same in mp even though its fully functional in ghost campaign touche beyond every wire putting one nail in the coffin at a time',
#  'so wait horses arthura poo hahaha storeplaystationcom',
#  'red dead redemption 3 in 2020 london leaks pictwittercom78nagfdkjf',
#  'pubg mobile does no harm to anyone banning it warm pakistans economy by immost 20crores year since its players buy the royal pass every 253 months and check it for its annual schedule 20 crores is the same estimat imrankhanpti ptaofficialpk',
#  'let me not upset you too ghostrecon you gonna fix this anytime soon or are u actually banning ppl',
#  'thank fuck they have that one emote if uno uno',
#  'niggas play i will throw the whole game if you take my fucking shit',
#  'looking back at old files on a hard drive its 2014 kids are stamping on cod you get voice messages full of rage life is good ive spent thousands of pounds im a great player',
#  'of',
#  'the music that plays in that sad snippet of the black ops cold war campaign is actually really good and fits the mood basically making the ost',
#  'live lets face it im addicted to league of legends twitchtvits_jackpot',
#  'i want to feel the way i feel because i watched hals battlegrounds for the first time fuck',
#  'oh but well have a vaccine by election day im sure this is pissing in donalds kfc bucket today']
